# %%
#Importing modules:
import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
#Package for flattening json in pandas dataframe
from pandas.io.json import json_normalize

# %%
#load json object
with open('../data/food_recall_data.json') as raw_data:
    data = json.load(raw_data)

# %%
#Putting data into a pandas df
#Looking at food_recall_data.json
#It shoes parent node is "results"
entire_df = json_normalize(data['results'])
entire_df.head(5)
# Out:
#                 address_1 address_2 center_classification_date         city  \
# 0        748 S Alameda St                             20120926  Los Angeles
# 1         4401 Foxdale St                             20120924    Irwindale
# 2          2315 Moore Ave                             20120927    Fullerton
# 3          2315 Moore Ave                             20120927    Fullerton
# 4  1720 Locust Grove Road                             20120921      Manheim
#
#   classification                                          code_info  \
# 0       Class II                                     not available.
# 1        Class I  UPC 7774523746, Use by dates 9/8/2012 or earli...
# 2       Class II               UPC 0-30871-33001-2, Item # 0291710.
# 3       Class II               UPC 0-52334-11659-9, Item # 0291661.
# 4       Class II  No codes; all product "Purchase by date shown ...
#
#          country                               distribution_pattern event_id  \
# 0  United States                                         California    63150
# 1  United States  Nationwide to following US States and Canada: ...    63062
# 2  United States                             Nationwide and Canada.    62991
# 3  United States                             Nationwide and Canada.    62991
# 4  United States  Product was distributed to specific wholesale ...    62465
#
#   initial_firm_notification            ...             product_type  \
# 0                    E-Mail            ...                     Food
# 1             Press Release            ...                     Food
# 2                    Letter            ...                     Food
# 3                    Letter            ...                     Food
# 4                 Telephone            ...                     Food
#
#                                    reason_for_recall recall_initiation_date  \
# 0  M & K Trading is recalling Korean Molluscan Sh...               20120921
# 1  Firm is voluntarily recalling, out of an abund...               20120831
# 2  The firm recalled due to a potential non-safet...               20120712
# 3  The firm recalled due to a potential non-safet...               20120712
# 4  FDA samples of product tested positive for Fum...               20120417
#
#   recall_number         recalling_firm report_date state      status  \
# 0   F-2396-2012      M & K Trading Inc    20121003    CA  Terminated
# 1   F-2382-2012    Ready Pac Foods Inc    20121003    CA  Terminated
# 2   F-2438-2012  Pulmuone Wildwood Inc    20121003    CA  Terminated
# 3   F-2436-2012  Pulmuone Wildwood Inc    20121003    CA  Terminated
# 4   F-2374-2012         Haldeman Mills    20121003    PA  Terminated
#
#   termination_date         voluntary_mandated
# 0         20120926  Voluntary: Firm Initiated
# 1         20121025  Voluntary: Firm Initiated
# 2         20121217  Voluntary: Firm Initiated
# 3         20121217  Voluntary: Firm Initiated
# 4         20130716  Voluntary: Firm Initiated
#
# [5 rows x 24 columns]

# %%
entire_df[["center_classification_date","report_date","termination_date"]] = entire_df[["center_classification_date","report_date","termination_date"]].apply(pd.to_datetime)

# %%
entire_df.head()
# Out:
#                 address_1 address_2 center_classification_date         city  \
# 0        748 S Alameda St                           2012-09-26  Los Angeles
# 1         4401 Foxdale St                           2012-09-24    Irwindale
# 2          2315 Moore Ave                           2012-09-27    Fullerton
# 3          2315 Moore Ave                           2012-09-27    Fullerton
# 4  1720 Locust Grove Road                           2012-09-21      Manheim
#
#   classification                                          code_info  \
# 0       Class II                                     not available.
# 1        Class I  UPC 7774523746, Use by dates 9/8/2012 or earli...
# 2       Class II               UPC 0-30871-33001-2, Item # 0291710.
# 3       Class II               UPC 0-52334-11659-9, Item # 0291661.
# 4       Class II  No codes; all product "Purchase by date shown ...
#
#          country                               distribution_pattern event_id  \
# 0  United States                                         California    63150
# 1  United States  Nationwide to following US States and Canada: ...    63062
# 2  United States                             Nationwide and Canada.    62991
# 3  United States                             Nationwide and Canada.    62991
# 4  United States  Product was distributed to specific wholesale ...    62465
#
#   initial_firm_notification            ...             product_type  \
# 0                    E-Mail            ...                     Food
# 1             Press Release            ...                     Food
# 2                    Letter            ...                     Food
# 3                    Letter            ...                     Food
# 4                 Telephone            ...                     Food
#
#                                    reason_for_recall recall_initiation_date  \
# 0  M & K Trading is recalling Korean Molluscan Sh...               20120921
# 1  Firm is voluntarily recalling, out of an abund...               20120831
# 2  The firm recalled due to a potential non-safet...               20120712
# 3  The firm recalled due to a potential non-safet...               20120712
# 4  FDA samples of product tested positive for Fum...               20120417
#
#   recall_number         recalling_firm report_date state      status  \
# 0   F-2396-2012      M & K Trading Inc  2012-10-03    CA  Terminated
# 1   F-2382-2012    Ready Pac Foods Inc  2012-10-03    CA  Terminated
# 2   F-2438-2012  Pulmuone Wildwood Inc  2012-10-03    CA  Terminated
# 3   F-2436-2012  Pulmuone Wildwood Inc  2012-10-03    CA  Terminated
# 4   F-2374-2012         Haldeman Mills  2012-10-03    PA  Terminated
#
#   termination_date         voluntary_mandated
# 0       2012-09-26  Voluntary: Firm Initiated
# 1       2012-10-25  Voluntary: Firm Initiated
# 2       2012-12-17  Voluntary: Firm Initiated
# 3       2012-12-17  Voluntary: Firm Initiated
# 4       2013-07-16  Voluntary: Firm Initiated
#
# [5 rows x 24 columns]

# %%
entire_df.columns
# Out:
# Index(['address_1', 'address_2', 'center_classification_date', 'city',
#        'classification', 'code_info', 'country', 'distribution_pattern',
#        'event_id', 'initial_firm_notification', 'more_code_info',
#        'postal_code', 'product_description', 'product_quantity',
#        'product_type', 'reason_for_recall', 'recall_initiation_date',
#        'recall_number', 'recalling_firm', 'report_date', 'state', 'status',
#        'termination_date', 'voluntary_mandated'],
#       dtype='object')

# %%
#Data clean up:
clean_df = entire_df.loc[:,["recalling_firm","product_type","country","state","report_date","termination_date","status","voluntary_mandated","classification"]]
clean_df.head()
# Out:
#           recalling_firm product_type        country state report_date  \
# 0      M & K Trading Inc         Food  United States    CA  2012-10-03
# 1    Ready Pac Foods Inc         Food  United States    CA  2012-10-03
# 2  Pulmuone Wildwood Inc         Food  United States    CA  2012-10-03
# 3  Pulmuone Wildwood Inc         Food  United States    CA  2012-10-03
# 4         Haldeman Mills         Food  United States    PA  2012-10-03
#
#   termination_date      status         voluntary_mandated classification
# 0       2012-09-26  Terminated  Voluntary: Firm Initiated       Class II
# 1       2012-10-25  Terminated  Voluntary: Firm Initiated        Class I
# 2       2012-12-17  Terminated  Voluntary: Firm Initiated       Class II
# 3       2012-12-17  Terminated  Voluntary: Firm Initiated       Class II
# 4       2013-07-16  Terminated  Voluntary: Firm Initiated       Class II

# %%
clean_df['year_reported'] = pd.DatetimeIndex(clean_df['report_date']).year
clean_df.head()
# Out:
#           recalling_firm product_type        country state report_date  \
# 0      M & K Trading Inc         Food  United States    CA  2012-10-03
# 1    Ready Pac Foods Inc         Food  United States    CA  2012-10-03
# 2  Pulmuone Wildwood Inc         Food  United States    CA  2012-10-03
# 3  Pulmuone Wildwood Inc         Food  United States    CA  2012-10-03
# 4         Haldeman Mills         Food  United States    PA  2012-10-03
#
#   termination_date      status         voluntary_mandated classification  \
# 0       2012-09-26  Terminated  Voluntary: Firm Initiated       Class II
# 1       2012-10-25  Terminated  Voluntary: Firm Initiated        Class I
# 2       2012-12-17  Terminated  Voluntary: Firm Initiated       Class II
# 3       2012-12-17  Terminated  Voluntary: Firm Initiated       Class II
# 4       2013-07-16  Terminated  Voluntary: Firm Initiated       Class II
#
#    year_reported
# 0           2012
# 1           2012
# 2           2012
# 3           2012
# 4           2012

# %%
firm_count_df = clean_df['recalling_firm'].value_counts()
firm_count_df.head()
# Out:
# Garden-Fresh Foods, Inc.      633
# Newly Weds Foods Inc          381
# Good Herbs, Inc.              353
# Blue Bell Creameries, L.P.    292
# Sunland, Incorporated         219
# Name: recalling_firm, dtype: int64

# %%
classification_count_df = clean_df["classification"].value_counts()
classification_count_df.head()
# Out:
# Class II              8874
# Class I               7707
# Class III             1009
# Not Yet Classified      31
# Name: classification, dtype: int64

# %%
state_group= clean_df.groupby(['state'])
stateCount = state_group.count()
stateCount
# Out:
#                   recalling_firm  product_type  country  report_date  \
# state
#                              127           127      127          127
# AK                            54            54       54           54
# AL                            28            28       28           28
# AR                            32            32       32           32
# AZ                           150           150      150          150
# Alberta                        2             2        2            2
# British Columbia               1             1        1            1
# CA                          2242          2242     2242         2242
# CO                           197           197      197          197
# CT                            90            90       90           90
# DC                             6             6        6            6
# DE                            23            23       23           23
# FL                           830           830      830          830
# GA                           297           297      297          297
# HI                            63            63       63           63
# IA                           269           269      269          269
# ID                           138           138      138          138
# IL                          1025          1025     1025         1025
# IN                           203           203      203          203
# KS                           192           192      192          192
# KY                           145           145      145          145
# LA                            39            39       39           39
# MA                           454           454      454          454
# MD                           171           171      171          171
# ME                            65            65       65           65
# MI                          1138          1138     1138         1138
# MN                           597           597      597          597
# MO                           237           237      237          237
# MS                            28            28       28           28
# MT                            16            16       16           16
# NC                           371           371      371          371
# ND                           101           101      101          101
# NE                            67            67       67           67
# NH                           217           217      217          217
# NJ                           677           677      677          677
# NM                           296           296      296          296
# NV                            71            71       71           71
# NY                           894           894      894          894
# New Brunswick                  1             1        1            1
# Nova Scotia                    6             6        6            6
# OH                           658           658      658          658
# OK                            40            40       40           40
# OR                           708           708      708          708
# Ontario                        3             3        3            3
# PA                           673           673      673          673
# PR                           189           189      189          189
# Quebec                         1             1        1            1
# RI                            35            35       35           35
# SC                            38            38       38           38
# SD                             2             2        2            2
# TN                           140           140      140          140
# TX                          1275          1275     1275         1275
# UT                            89            89       89           89
# VA                           128           128      128          128
# VT                            35            35       35           35
# WA                           941           941      941          941
# WI                          1095          1095     1095         1095
# WV                             6             6        6            6
# WY                             5             5        5            5
#
#                   termination_date  status  voluntary_mandated  \
# state
#                                112     127                 127
# AK                              54      54                  54
# AL                              26      28                  28
# AR                              27      32                  32
# AZ                             147     150                 150
# Alberta                          2       2                   2
# British Columbia                 1       1                   1
# CA                            2124    2242                2242
# CO                             183     197                 197
# CT                              79      90                  90
# DC                               6       6                   6
# DE                              23      23                  23
# FL                             569     830                 830
# GA                             256     297                 297
# HI                              52      63                  63
# IA                             251     269                 269
# ID                             137     138                 138
# IL                             427    1025                1025
# IN                             195     203                 203
# KS                             190     192                 192
# KY                             139     145                 145
# LA                              38      39                  39
# MA                             433     454                 454
# MD                             148     171                 171
# ME                              65      65                  65
# MI                            1070    1138                1138
# MN                             532     597                 597
# MO                             234     237                 237
# MS                              28      28                  28
# MT                              15      16                  16
# NC                             249     371                 371
# ND                              97     101                 101
# NE                              64      67                  67
# NH                             216     217                 217
# NJ                             581     677                 677
# NM                             296     296                 296
# NV                              43      71                  71
# NY                             821     894                 894
# New Brunswick                    1       1                   1
# Nova Scotia                      0       6                   6
# OH                             587     658                 658
# OK                              39      40                  40
# OR                             688     708                 708
# Ontario                          2       3                   3
# PA                             632     673                 673
# PR                             162     189                 189
# Quebec                           1       1                   1
# RI                              23      35                  35
# SC                              18      38                  38
# SD                               0       2                   2
# TN                             137     140                 140
# TX                            1238    1275                1275
# UT                              76      89                  89
# VA                             101     128                 128
# VT                              33      35                  35
# WA                             930     941                 941
# WI                            1038    1095                1095
# WV                               2       6                   6
# WY                               4       5                   5
#
#                   classification  year_reported
# state
#                              127            127
# AK                            54             54
# AL                            28             28
# AR                            32             32
# AZ                           150            150
# Alberta                        2              2
# British Columbia               1              1
# CA                          2242           2242
# CO                           197            197
# CT                            90             90
# DC                             6              6
# DE                            23             23
# FL                           830            830
# GA                           297            297
# HI                            63             63
# IA                           269            269
# ID                           138            138
# IL                          1025           1025
# IN                           203            203
# KS                           192            192
# KY                           145            145
# LA                            39             39
# MA                           454            454
# MD                           171            171
# ME                            65             65
# MI                          1138           1138
# MN                           597            597
# MO                           237            237
# MS                            28             28
# MT                            16             16
# NC                           371            371
# ND                           101            101
# NE                            67             67
# NH                           217            217
# NJ                           677            677
# NM                           296            296
# NV                            71             71
# NY                           894            894
# New Brunswick                  1              1
# Nova Scotia                    6              6
# OH                           658            658
# OK                            40             40
# OR                           708            708
# Ontario                        3              3
# PA                           673            673
# PR                           189            189
# Quebec                         1              1
# RI                            35             35
# SC                            38             38
# SD                             2              2
# TN                           140            140
# TX                          1275           1275
# UT                            89             89
# VA                           128            128
# VT                            35             35
# WA                           941            941
# WI                          1095           1095
# WV                             6              6
# WY                             5              5

# %%
splot = stateCount.plot.pie(y='country', figsize=(40, 40))

# %%
country_group= clean_df.groupby(['country'])
countryCount = country_group.count()
countryCount
# Out:
#                           recalling_firm  product_type  state  report_date  \
# country
# Armenia                                4             4      4            4
# Australia                              1             1      1            1
# Belgium                                1             1      1            1
# Canada                                75            75     75           75
# Chile                                  5             5      5            5
# China                                  1             1      1            1
# Costa Rica                             2             2      2            2
# Dominican Republic (the)               1             1      1            1
# Egypt                                  3             3      3            3
# France                                10            10     10           10
# Germany                                1             1      1            1
# Guatemala                              2             2      2            2
# Israel                                 4             4      4            4
# Italy                                  3             3      3            3
# Korea (the Republic of)                5             5      5            5
# Mexico                                 7             7      7            7
# Poland                                 1             1      1            1
# Sweden                                 1             1      1            1
# Taiwan                                12            12     12           12
# Thailand                               1             1      1            1
# United Kingdom                         1             1      1            1
# United States                      17480         17480  17480        17480
#
#                           termination_date  status  voluntary_mandated  \
# country
# Armenia                                  4       4                   4
# Australia                                1       1                   1
# Belgium                                  0       1                   1
# Canada                                  63      75                  75
# Chile                                    5       5                   5
# China                                    1       1                   1
# Costa Rica                               2       2                   2
# Dominican Republic (the)                 1       1                   1
# Egypt                                    3       3                   3
# France                                  10      10                  10
# Germany                                  1       1                   1
# Guatemala                                2       2                   2
# Israel                                   4       4                   4
# Italy                                    3       3                   3
# Korea (the Republic of)                  1       5                   5
# Mexico                                   2       7                   7
# Poland                                   1       1                   1
# Sweden                                   1       1                   1
# Taiwan                                  12      12                  12
# Thailand                                 1       1                   1
# United Kingdom                           1       1                   1
# United States                        15523   17480               17480
#
#                           classification  year_reported
# country
# Armenia                                4              4
# Australia                              1              1
# Belgium                                1              1
# Canada                                75             75
# Chile                                  5              5
# China                                  1              1
# Costa Rica                             2              2
# Dominican Republic (the)               1              1
# Egypt                                  3              3
# France                                10             10
# Germany                                1              1
# Guatemala                              2              2
# Israel                                 4              4
# Italy                                  3              3
# Korea (the Republic of)                5              5
# Mexico                                 7              7
# Poland                                 1              1
# Sweden                                 1              1
# Taiwan                                12             12
# Thailand                               1              1
# United Kingdom                         1              1
# United States                      17480          17480

# %%
countryplot = countryCount.plot.pie(y='state', figsize=(20, 20))

# %%
yearly_count_df = clean_df["year_reported"].value_counts()
yearly_count_df.head()

# %%
status_count_df = clean_df['status'].value_counts()
status_count_df.head()

# %%
vol_man_count_df = clean_df['voluntary_mandated'].value_counts()
vol_man_count_df.head()

# %%
# Create connection to SQL Database
from sqlalchemy import create_engine
engine = create_engine('sqlite:///../data/food_recall.sqlite', echo=False)

# %%
# Create new table on SQL database
clean_df.to_sql('food_recall', con=engine)

# %%
engine.execute('SELECT * FROM food_recall').fetchall()
